# %%
pip install ete3
# Out:
# ...
#      |████████████████████████████████| 4.7 MB 32.2 MB/s
# ...
#   Created wheel for ete3: filename=ete3-3.1.2-py3-none-any.whl size=2273013 sha256=6b076688b800d2dca6c075c5f9b8ff52bc8b72832a1dbc45608d333d74b347b7
#   Stored in directory: /root/.cache/pip/wheels/17/fd/e2/6ac384d8c2484789304657dde01b96d7ab83f4f1dd96d266df
# Successfully built ete3
# ...

# %%
from ete3 import Tree

# %%
camel_virus = 'MT085175.1'

# %%
generated = Tree('tree.txt', format=1)

# %%
print("Before:")
print(generated)
# Out:
# Before:
#
#    /-SARScoronavirusHZS2-D
#   |
#   |--SARScoronavirusSino3-11
#   |
#   |   /-SARScoronavirusHZS2-C
#   |  |
#   |  |   /-SARScoronavirusHKU-39849isolateUOB
#   |  |  |
#   |  |  |               /-SARScoronavirusBJ182-12
#   |  |  |              |
#   |  |  |            /-|   /-SARScoronavirusBJ182-4
#   |  |  |           |  |  |
#   |  |  |           |  |  |--SARScoronavirusBJ182a
#   |  |  |           |   \-|
#   |  |  |           |     |--SARScoronavirusBJ182b
#   |  |  |           |     |
# --|  |  |           |      \-SARScoronavirusBJ182-8
#   |  |  |           |
#   |  |  |         /-|      /-SARScoronavirusGZ02
#   |  |  |        |  |   /-|
#   |  |  |        |  |  |  |   /-SARScoronavirusSZ3
#   |  |  |        |  |  |   \-|
#   |  |  |        |  |  |      \-SARScoronavirusSZ16
#   |  |  |        |  |  |
#   |  |  |        |  |  |      /-SARScoronavirusZS-B
#   |  |  |        |  |  |   /-|
#   |  |  |        |  |  |  |   \-SARScoronavirusZS-C
# ...

# %%
generated.set_outgroup(camel_virus)

# %%
print("After:")
print(generated)
# Out:
# After:
#
#    /-SARScoronavirusHZS2-D
#   |
#   |--SARScoronavirusSino3-11
#   |
#   |   /-SARScoronavirusHZS2-C
#   |  |
#   |  |   /-SARScoronavirusHKU-39849isolateUOB
#   |  |  |
#   |  |  |               /-SARScoronavirusBJ182-12
#   |  |  |              |
#   |  |  |            /-|   /-SARScoronavirusBJ182-4
#   |  |  |           |  |  |
#   |  |  |           |  |  |--SARScoronavirusBJ182a
#   |  |  |           |   \-|
#   |  |  |           |     |--SARScoronavirusBJ182b
#   |  |  |           |     |
# --|  |  |           |      \-SARScoronavirusBJ182-8
#   |  |  |           |
#   |  |  |         /-|      /-SARScoronavirusGZ02
#   |  |  |        |  |   /-|
#   |  |  |        |  |  |  |   /-SARScoronavirusSZ3
#   |  |  |        |  |  |   \-|
#   |  |  |        |  |  |      \-SARScoronavirusSZ16
#   |  |  |        |  |  |
#   |  |  |        |  |  |      /-SARScoronavirusZS-B
#   |  |  |        |  |  |   /-|
#   |  |  |        |  |  |  |   \-SARScoronavirusZS-C
# ...
